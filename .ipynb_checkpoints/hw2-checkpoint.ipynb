# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from collections import Counter

from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, ExtraTreesClassifier, VotingClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold, learning_curve, train_test_split, KFold
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

sns.set(style='white', context='notebook', palette='deep')

dataset = pd.read_csv("./train.csv")

# Check for Null Data
dataset.isnull().sum()

# Replace All Null Data in NaN
dataset = dataset.fillna(np.nan)

# Get data types
# print(dataset.dtypes)

# # Peek at data
# print(dataset.head(4))

# Reformat Column We Are Predicting
dataset['income']=dataset['income'].map({'<=50K': 0, '>50K': 1, '<=50K.': 0, '>50K.': 1})
print(dataset.head(4))

# Identify Numeric features
numeric_features = ['age','fnlwgt','educational-num','capital-gain','capital-loss','hours-per-week','income']

# Identify Categorical features
cat_features = ['workclass','education','marital-status', 'occupation', 'relationship', 'race', 'sex', 'native']
# Out:
#    age workclass  fnlwgt     education  educational-num      marital-status
# 0   52   Private  210736  Some-college               10  Married-civ-spouse  \
# 1   62   Private  209844  Some-college               10            Divorced
# 2   25   Private  410240       HS-grad                9       Never-married
# 3   28   Private   90547       HS-grad                9  Married-civ-spouse
#
#         occupation relationship   race  gender  capital-gain  capital-loss
# 0  Exec-managerial      Husband  White    Male          3103             0  \
# 1     Adm-clerical    Unmarried  White  Female             0             0
# 2     Craft-repair    Own-child  White    Male             0             0
# 3    Other-service         Wife  Black  Female             0             0
#
#    hours-per-week native-country  income
# 0              55  United-States       1
# 1              30  United-States       0
# 2              40  United-States       0
# 3              23  United-States       0

# %%
# Count of >50K & <=50K
sns.countplot(dataset['income'], label="Count")
plt.show()

# %%
len(dataset[dataset['income'] == 1])
# Out:
# 9338

# %%
len(dataset[dataset['income'] == 0])
# Out:
# 29735

# %%
# Correlation matrix between numerical values
g = sns.heatmap(dataset[numeric_features].corr(),annot=True, fmt = ".2f", cmap = "coolwarm")
plt.show()

# %%
# Explore Education Num vs Income
g = sns.catplot(x="educational-num", y="income", data=dataset, kind="bar", height=6, aspect=1.5)
g.despine(left=True)
g = g.set_ylabels(">50K probability")

# %%
# Explore Hours Per Week vs Income
g  = sns.catplot(x="hours-per-week",y="income",data=dataset,kind="bar", height=6, aspect=1.5)
g.despine(left=True)
g = g.set_ylabels(">50K probability")

# %%
# Explore Age vs Income
g = sns.FacetGrid(dataset, col='income')
g = g.map(sns.distplot, "age")
plt.show()
# Out:
# /Users/ctu/.local/share/virtualenvs/hw2-yXLUqKre/lib/python3.11/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# /Users/ctu/.local/share/virtualenvs/hw2-yXLUqKre/lib/python3.11/site-packages/seaborn/axisgrid.py:848: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)

# %%
# Explore Native Nation vs Income
g = sns.barplot(x="native-country", y="income", data=dataset)
g = g.set_ylabel("Income >50K Probability")
plt.show()

# %%
# Explore Sex vs Income
g = sns.barplot(x="gender",y="income",data=dataset)
g = g.set_ylabel("Income >50K Probability")
plt.show()

# %%
# Explore Relationship vs Income
g = sns.catplot(x="relationship",y="income",data=dataset,kind="bar", height=6, aspect=1.5,
palette = "muted")
g.despine(left=True)
g = g.set_ylabels("Income >50K Probability")
plt.show()

# %%
# Explore Marital Status vs Income
g = sns.catplot(x="marital-status",y="income",data=dataset,kind="bar", height=6, aspect=1.5,
palette = "muted")
g.despine(left=True)
g = g.set_ylabels("Income >50K Probability")
plt.show()

# %%
# Explore Workclass vs Income
g = sns.catplot(x="workclass",y="income",data=dataset,kind="bar", height=6, aspect=1.5, palette = "muted")
g.despine(left=True)
g = g.set_ylabels("Income >50K Probability")
plt.show()

# %%
# Convert gender value to 0 and 1
dataset["gender"] = dataset["gender"].map({"Male": 0, "Female":1})

# %%
# Create Married Column - Binary Yes(1) or No(0)
dataset["marital-status"] = dataset["marital-status"].replace(['Never-married','Divorced','Separated','Widowed'], 'Single')
dataset["marital-status"] = dataset["marital-status"].replace(['Married-civ-spouse','Married-spouse-absent','Married-AF-spouse'], 'Married')
dataset["marital-status"] = dataset["marital-status"].map({"Married":1, "Single":0})
dataset["marital-status"] = dataset["marital-status"].astype(int)

# %%
dataset
# Out:
#        age workclass  fnlwgt     education  educational-num  marital-status
# 0       52   Private  210736  Some-college               10               1  \
# 1       62   Private  209844  Some-college               10               0
# 2       25   Private  410240       HS-grad                9               0
# 3       28   Private   90547       HS-grad                9               1
# 4       28   Private  132326       HS-grad                9               0
# ...    ...       ...     ...           ...              ...             ...
# 39068   40   Private  116103  Some-college               10               0
# 39069   19   Private  284652  Some-college               10               0
# 39070   29   Private  130010       Masters               14               1
# 39071   42         ?  175935       HS-grad                9               0
# 39072   35   Private  411395  Some-college               10               1
#
#             occupation relationship   race  gender  capital-gain
# 0      Exec-managerial      Husband  White       0          3103  \
# 1         Adm-clerical    Unmarried  White       1             0
# 2         Craft-repair    Own-child  White       0             0
# 3        Other-service         Wife  Black       1             0
# 4         Adm-clerical    Own-child  White       0             0
# ...                ...          ...    ...     ...           ...
# 39068     Craft-repair    Unmarried  White       0          4934
# 39069     Adm-clerical    Own-child  White       1             0
# 39070  Exec-managerial      Husband  White       0             0
# 39071                ?    Unmarried  White       0             0
# 39072  Exec-managerial      Husband  White       0             0
#
#        capital-loss  hours-per-week native-country  income
# 0                 0              55  United-States       1
# 1                 0              30  United-States       0
# 2                 0              40  United-States       0
# 3                 0              23  United-States       0
# 4                 0              40  United-States       0
# ...             ...             ...            ...     ...
# 39068             0              47  United-States       1
# 39069             0              15  United-States       0
# 39070             0              40  United-States       1
# 39071             0              40  United-States       0
# 39072             0              36  United-States       0
#
# [39073 rows x 15 columns]

# %%
dataset.drop(labels=["workclass","education","occupation","relationship","race","native-country"], axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 dataset.drop(labels=["workclass","education","occupation","relationship","race","native-country"], axis = 1, inplace = True)
#       2 print('Dataset with Dropped Labels')
#       3 print(dataset.head())
#
# File ~/.local/share/virtualenvs/hw2-yXLUqKre/lib/python3.11/site-packages/pandas/core/frame.py:5268, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5120 def drop(
#    5121     self,
#    5122     labels: IndexLabel = None,
#    (...)
#    5129     errors: IgnoreRaise = "raise",
#    5130 ) -> DataFrame | None:
#    5131     """
#    5132     Drop specified labels from rows or columns.
#    5133
#    (...)
#    5266             weight  1.0     0.8
#    5267     """
# -> 5268     return super().drop(
#    5269         labels=labels,
#    5270         axis=axis,
#    5271         index=index,
#    5272         columns=columns,
#    5273         level=level,
#    5274         inplace=inplace,
#    5275         errors=errors,
#    5276     )
#
# File ~/.local/share/virtualenvs/hw2-yXLUqKre/lib/python3.11/site-packages/pandas/core/generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~/.local/share/virtualenvs/hw2-yXLUqKre/lib/python3.11/site-packages/pandas/core/generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~/.local/share/virtualenvs/hw2-yXLUqKre/lib/python3.11/site-packages/pandas/core/indexes/base.py:6696, in Index.drop(self, labels, errors)
#    6694 if mask.any():
#    6695     if errors != "ignore":
# -> 6696         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6697     indexer = indexer[~mask]
#    6698 return self.delete(indexer)
#
# KeyError: "['workclass', 'education', 'occupation', 'relationship', 'race', 'native-country'] not found in axis"

# %%
print('Dataset with Dropped Labels')
print(dataset.head())
# Out:
# Dataset with Dropped Labels
#    age  fnlwgt  educational-num  marital-status  gender  capital-gain
# 0   52  210736               10               1       0          3103  \
# 1   62  209844               10               0       1             0
# 2   25  410240                9               0       0             0
# 3   28   90547                9               1       1             0
# 4   28  132326                9               0       0             0
#
#    capital-loss  hours-per-week  income
# 0             0              55       1
# 1             0              30       0
# 2             0              40       0
# 3             0              23       0
# 4             0              40       0

# %%
###################################################
##################### MODELING #####################
####################################################
# Split-out Validation Dataset and Create Test Variables
array = dataset.values
X = array[:,0:8]
Y = array[:,8]
print('Split Data: X')
print(X)
print('Split Data: Y')
print(Y)
validation_size = 0.20
# seed = 7
seed = None
num_folds = 10
scoring = 'accuracy'

X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y, test_size=validation_size, random_state=seed)
# train_data, test_data, train_labels, test_labels = train_test_split(data, labels, test_size=0.2, shuffle=False, random_state=42)

# Params for Random Forest
num_trees = 100
max_features = 3

#Spot Check 5 Algorithms (LR, LDA, KNN, CART, GNB, SVM)
models = []
models.append(('LR', LogisticRegression()))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('RF', RandomForestClassifier(n_estimators=num_trees, max_features=max_features)))
#models.append(('SVM', SVC()))
# evalutate each model in turn
results = []
names = []
for name, model in models:
    kfold = KFold(n_splits=10, random_state=seed)
    cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring='accuracy')
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# Split Data: X
# [[    52 210736     10 ...   3103      0     55]
#  [    62 209844     10 ...      0      0     30]
#  [    25 410240      9 ...      0      0     40]
#  ...
#  [    29 130010     14 ...      0      0     40]
#  [    42 175935      9 ...      0      0     40]
#  [    35 411395     10 ...      0      0     36]]
# Split Data: Y
# [1 0 0 ... 1 0 0]
# LR: 0.798996 (0.005215)
# LDA: 0.828876 (0.005557)
# KNN: 0.774394 (0.003753)
# CART: 0.806738 (0.006819)
# NB: 0.796500 (0.005716)
# RF: 0.841513 (0.004190)

# %%
fig = plt.figure()
fig.suptitle('Algorith Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()

# %%
# Commented Out to Reduce Script Time - Took 20 Minutes to run.
# best n_estimator = 250
# best max_feature = 5
# Tune Random Forest
n_estimators = np.array([50,100,150,200,250])
max_features = np.array([1,2,3,4,5])
param_grid = dict(n_estimators=n_estimators,max_features=max_features)
model = RandomForestClassifier()
kfold = KFold(n_splits=num_folds, random_state=seed)
grid = GridSearchCV(estimator=model, param_grid=param_grid, scoring=scoring, cv=kfold)
grid_result = grid.fit(X_train, Y_train)
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.843208 using {'max_features': 3, 'n_estimators': 150}
# 0.841800 (0.005084) with: {'max_features': 1, 'n_estimators': 50}
# 0.841544 (0.004785) with: {'max_features': 1, 'n_estimators': 100}
# 0.841832 (0.004977) with: {'max_features': 1, 'n_estimators': 150}
# 0.843080 (0.004648) with: {'max_features': 1, 'n_estimators': 200}
# 0.842888 (0.004474) with: {'max_features': 1, 'n_estimators': 250}
# 0.842536 (0.004986) with: {'max_features': 2, 'n_estimators': 50}
# 0.842632 (0.005151) with: {'max_features': 2, 'n_estimators': 100}
# 0.842024 (0.005518) with: {'max_features': 2, 'n_estimators': 150}
# 0.842568 (0.004952) with: {'max_features': 2, 'n_estimators': 200}
# 0.842152 (0.004042) with: {'max_features': 2, 'n_estimators': 250}
# 0.841768 (0.004473) with: {'max_features': 3, 'n_estimators': 50}
# 0.841832 (0.003456) with: {'max_features': 3, 'n_estimators': 100}
# 0.843208 (0.004995) with: {'max_features': 3, 'n_estimators': 150}
# 0.842696 (0.004824) with: {'max_features': 3, 'n_estimators': 200}
# 0.842152 (0.004418) with: {'max_features': 3, 'n_estimators': 250}
# 0.842120 (0.003926) with: {'max_features': 4, 'n_estimators': 50}
# 0.842056 (0.004350) with: {'max_features': 4, 'n_estimators': 100}
# 0.841256 (0.003209) with: {'max_features': 4, 'n_estimators': 150}
# 0.841672 (0.004689) with: {'max_features': 4, 'n_estimators': 200}
# 0.842152 (0.003948) with: {'max_features': 4, 'n_estimators': 250}
# 0.841576 (0.003323) with: {'max_features': 5, 'n_estimators': 50}
# 0.841928 (0.002913) with: {'max_features': 5, 'n_estimators': 100}
# 0.841800 (0.004139) with: {'max_features': 5, 'n_estimators': 150}
# 0.841608 (0.004774) with: {'max_features': 5, 'n_estimators': 200}
# 0.842248 (0.004274) with: {'max_features': 5, 'n_estimators': 250}

# %%
random_forest = RandomForestClassifier(n_estimators=250,max_features=5)
random_forest.fit(X_train, Y_train)
predictions = random_forest.predict(X_validation)
print("Accuracy: %s%%" % (100*accuracy_score(Y_validation, predictions)))
print(confusion_matrix(Y_validation, predictions))
print(classification_report(Y_validation, predictions))
# Out:
# Accuracy: 84.00511836212412%
# [[5448  490]
#  [ 760 1117]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90      5938
#            1       0.70      0.60      0.64      1877
#
#     accuracy                           0.84      7815
#    macro avg       0.79      0.76      0.77      7815
# weighted avg       0.83      0.84      0.84      7815

# %%
predictions
# Out:
# array([0, 1, 1, ..., 0, 0, 1])

# %%
Y_validation
# Out:
# array([0, 0, 1, ..., 0, 0, 1])

# %%
X_validation
# Out:
# array([[    19, 196857,     10, ...,      0,      0,     20],
#        [    45, 122206,      9, ...,      0,      0,     40],
#        [    30, 186932,     16, ...,   5178,      0,     75],
#        ...,
#        [    35,  37655,      9, ...,      0,      0,     60],
#        [    30, 203488,     13, ...,      0,      0,     60],
#        [    58, 314153,      9, ...,      0,      0,     40]])

# %%
random_forest_test = RandomForestClassifier(n_estimators=250,max_features=5)
random_forest_test.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(max_features=5, n_estimators=250)

# %%
random_forest.predict(X_validation)
# Out:
# array([0, 1, 1, ..., 0, 0, 1])

# %%
test_dataset = pd.read_csv("./test_X.csv")
test_dataset = test_dataset.fillna(np.nan)

# %%
# Convert gender value to 0 and 1
test_dataset["gender"] = test_dataset["gender"].map({"Male": 0, "Female":1})

# Create Married Column - Binary Yes(1) or No(0)
test_dataset["marital-status"] = test_dataset["marital-status"].replace(['Never-married','Divorced','Separated','Widowed'], 'Single')
test_dataset["marital-status"] = test_dataset["marital-status"].replace(['Married-civ-spouse','Married-spouse-absent','Married-AF-spouse'], 'Married')
test_dataset["marital-status"] = test_dataset["marital-status"].map({"Married":1, "Single":0})
test_dataset["marital-status"] = test_dataset["marital-status"].astype(int)

test_dataset.drop(labels=["workclass","education","occupation","relationship","race","native-country"], axis = 1, inplace = True)

# %%
test_dataset
# Out:
#       age  fnlwgt  educational-num  marital-status  gender  capital-gain
# 0      42  172307               10               1       0             0  \
# 1      39  240468                9               0       0             0
# 2      44  151089               14               1       0             0
# 3      38  269318               13               1       0          5178
# 4      31  161153                9               1       0             0
# ...   ...     ...              ...             ...     ...           ...
# 9764   42  167357               10               0       1             0
# 9765   37   98776                9               1       0             0
# 9766   32  137875               10               0       1             0
# 9767   49  102771               13               1       0             0
# 9768   45  200471               10               1       0             0
#
#       capital-loss  hours-per-week
# 0                0              45
# 1                0              42
# 2             1887              60
# 3                0              50
# 4                0              45
# ...            ...             ...
# 9764           213              40
# 9765             0              15
# 9766             0              30
# 9767             0              52
# 9768          2415              40
#
# [9769 rows x 8 columns]

# %%
X_validation[0]
# Out:
# array([    19, 196857,     10,      0,      1,      0,      0,     20])

# %%
random_forest = RandomForestClassifier(n_estimators=250,max_features=5)
random_forest.fit(X_train, Y_train)
predictions = random_forest.predict(test_dataset)
# Out:
# /Users/ctu/.local/share/virtualenvs/hw2-yXLUqKre/lib/python3.11/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(

# %%
predictions
# Out:
# array([0, 0, 1, ..., 0, 1, 1])

# %%
len(predictions)
# Out:
# 9769

# %%
save_data = np.array(predictions)
save_data_index = list(range(len(save_data)))

# %%
df = pd.DataFrame({"id": save_data_index, "income": save_data})

# %%
df
# Out:
#         id  income
# 0        0       0
# 1        1       0
# 2        2       1
# 3        3       1
# 4        4       0
# ...    ...     ...
# 9764  9764       0
# 9765  9765       0
# 9766  9766       0
# 9767  9767       1
# 9768  9768       1
#
# [9769 rows x 2 columns]

# %%
df.to_csv("data.csv", index=False)
